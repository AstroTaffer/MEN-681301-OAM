# %%
from astropy.table import Table

radius=5
target="HD12"
sed=Table.read(f"https://vizier.cds.unistra.fr/viz-bin/sed?-c={target}&-c.rs={radius}")
print(sed)


import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot()
ax.set_xlabel('freq (GHz)')
ax.set_ylabel('Flux (Jsky)')
  
ax.scatter(sed["sed_freq"], sed["sed_flux"])
plt.show()
# Out:
#    _RAJ2000       _DEJ2000    ... sed_eflux      sed_filter
#      deg            deg       ...     Jy
# -------------- -------------- ... --------- --------------------
#   1.2622400876 -59.8281212550 ...        --            Johnson:V
#   1.2622400876 -59.8281212550 ...      0.01               HIP:VT
#   1.2622400876 -59.8281212550 ...     0.008               HIP:BT
#   1.2622400876 -59.8281212550 ...         0               HIP:Hp
#   1.2622480736 -59.8280665100 ...        --            Johnson:V
#   1.2622480736 -59.8280665100 ...      0.01               HIP:VT
#            ...            ... ...       ...                  ...
#   1.2622400000 -59.8281211100 ...        --              WISE:W3
#   1.2622400000 -59.8281211100 ...        --            AKARI:S9W
#   1.2622400000 -59.8281211100 ...        --              WISE:W1
#   1.2622400000 -59.8281211100 ...        -- Subaru/Suprime:IA598
#   1.2622400000 -59.8281211100 ...        --               HIP:Hp
#   1.2622361100 -59.8281488900 ...        --               Gaia:G
#   1.2622361100 -59.8281488900 ...        --               Gaia:G
# Length = 235 rows
